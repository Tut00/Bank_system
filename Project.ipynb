# %%
#This work Done by group 12:
#Murtadha Alghwainem, 201850160,(50%)
#Turki Alzahrani, 201936550,(50%)

#1.
from time import sleep
cardNumber = 0
file = "cardNumber"
currentPIN=0
def create():                 #create a new account.
    file="cardNumber"
    card_num=input("Enter your Card Number : ")
    n=True
    outputC=open( file + ".txt","w") #open file witch name is cardNumber.txt
    outputC.write("Card Number is : ")
    while n :              #Check if the Card Number Valid or not regarding to these conditions:
        if len(card_num)==4:     # length of the card number is 4
            if card_num.isnumeric():    # Type of Card number is Number
                if len(set(card_num))!=4 :   # To Check if there any repeated number
                    print("Unvalid Card Number.")
                    card_num=input("Enter Card Number : ")
                else:
                    outputC.write(card_num) 
                    n=False
            else:
                print("Unvalid Card Number.")
                card_num=input("Enter Card Number : ")
        else:
            print("Unvalid Card Number.")
            card_num=input("Enter Card Number : ")
    outputC.write("\n")
#___________________________________________________________________________________________________________________________#
    pin=input("Enter PIN Code: ")
    outputC.write("PIN code is: ")
    n=True
    while n :          #Check if the PIN code Valid or not regarding to these conditions
        if len(pin)==4: # length of the PIN code is 4
            if pin.isdigit(): # Type of PIN code is digit
                if len(set(pin))!=4 :  # To Check if there any repeated number
                    print("Unvalid PIN Code.")
                    pin=input("Enter PIN Code: ")
                else:
                    outputC.write(pin)
                    n=False
            else:
                print("Unvalid PIN Code.")
                pin=input("Enter PIN Code: ")
        else:
            print("Unvalid PIN Code.")
            pin=input("Enter PIN Code: ")
    outputC.write("\n")
#_______________________________________________________________________________________________________________________#     
    e_Mail=input("Enter you Email : ")
    outputC.write("Email address is: ")
    n=True
    while n:
        if len(e_Mail)==23 and e_Mail.endswith("@kfupm.edu.sa") and e_Mail[0]=="s" and e_Mail[1:9].isdigit() :
            outputC.write(e_Mail+"\n") # To check if the email belong to a student at KFUPM or not
            n=False
        else:
            print("Unvalid Email.")
            e_Mail=input("Enter your Email : ")
#_________________________________________________________________________________________________________________#
    extra_Services=input("Enter The services that you want (seprte it by commaas(,)): ")
    outputC.write("You extra service(s) : ")
    n=True
    extra_Servicesw=extra_Services.split() #Extra services without space(gab)
    while n:
        for strr in extra_Servicesw :
            if len(strr)>=2: # To keep sure that user input at least one extra service
                outputC.write(strr+"\n")
                n=False
            else:
                print("You should at least enter one service.")
                extra_Services=input("Enter The services that you want (seprte it by commaas(,)): ")  
    outputC.write("Balance : 0.0")
    outputC.close()
    sleep(2)
    
#2.   
def login():
    file="cardNumber"
    global cardNumber # Calling a global varibel 
    cardNumber=input("Enter your card number : ")
    outputC=open( file + ".txt","r")
    line1=outputC.readline()
    n=True
    while n:
        if str(cardNumber)==str(line1[17:21]): # Checking if the input card number same as card number in file or not
            n=False
        else:
            print("Wrong card number")
            cardNumber=input("Enter your card number : ")
#_________________________________________________________        
    global currentPIN # Calling a global varibel
    currentPIN=input("Enter your Pin code : ")
    line2=outputC.readline()
    n=True
    while n:
        if str(currentPIN)==str(line2[13:17]):  # Checking if the input PIN code same as PIN code in file or not
            n=False
        else:
            print("Wrong pin code")
            currentPIN=input("Enter your pin code : ")
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program")  # list of orders

#3.
def show(file):  # This feature make the user able to see his/her account information.
    infile=open( file + ".txt","r")
    for line in infile:
        line=line.rstrip()
        print(line)
    sleep(2)
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program") # list of orders
    
#4.
def changePINFun(currentPIN, cardNumber, file): # This feature make the user able to change his PIN code.
    infile=open(file+".txt","r")
    sinfile=open("new file.txt","w")
    line0=infile.readline() 
    line01=infile.readline()
    if str(cardNumber) == str(line0[17:21]):
        if str(currentPIN)==str(line01[13:17]):
            sinfile.write(line0)
            sinfile.write(line01)
            for line in infile:
        
                sinfile.write(line)
            infile.close()
            sinfile.close()
            infile=open(file+".txt","w")
            sinfile=open("new file.txt","r")
            line1=sinfile.readline()
            infile.write(line1)
            line2=sinfile.readline()
            newPIN=input("Enter the new PIN code: ")
            infile.write("PIN code is: ")
            n=True
            while n : #Cheking the condition of the new PIN code
                if len(newPIN)==4:
                    if newPIN.isdigit():
                        if len(set(newPIN))!=4 :
                            print("Unvalid PIN Code.")
                            newPIN=input("Enter PIN Code: ")
                        else:
                            infile.write(newPIN)
                            n=False
                    else:
                        print("Unvalid PIN Code.")
                        newPIN=input("Enter PIN Code: ")
                else:
                    print("Unvalid PIN Code.")
                    newPIN=input("Enter PIN Code: ")
            infile.write("\n")
            for line in sinfile:
                infile.write(line)
            infile.close()
            sinfile.close()
        else:
                print("wrong PIN")
                infile.close()
                sinfile.close()
    else:
        print("Wrong card number")
        infile.close()
        sinfile.close()
    sleep(2)
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program")


#5.
def withdrawFun(money, cardNumber, file): #This function enable the user to withdraw money from the account
    infile=open( file + ".txt","r")
    line1=infile.readline()
    list1=[]
    list2=[]
    if str(cardNumber) in line1 : # check if the card number is correct 
        line1=line1.rstrip()
        line1=line1.split()
        list1.append(line1)
        for line in infile:
            line=line.rstrip()
            line=line.split()
            list1.append(line)
        balance = float(((list1[4])[2]))
        while money > balance : # check if the money enough to withdraw
            print ("Not enough balance please try again")
            money=float(input(""))      
        balance=balance-money
        (list1[4])[2]="%.2f"%balance
        outfile=open( file + ".txt","w")
        for n in list1:
            for k in n:
                outfile.write(str(k))
                outfile.write(" ")
            outfile.write("\n")  
        from time import ctime 
        outfile.write("you have withdrawn  " + str(money) + " SR in this date: "+ctime()) # writing the time of the function whene it used
        outfile.close()
        print("Done")
    else :
        print("Unvalid Card Number.")
    sleep(2)
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program")

#6.
def depositFun(money, cardNumber, file): #This function enables the user to deposit money from the account
    infile=open( file + ".txt","r")
    line1=infile.readline()
    list1=[]
    list2=[]
    if str(cardNumber) in line1 :
        line1=line1.rstrip()
        line1=line1.split()
        list1.append(line1)
        for line in infile:
            line=line.rstrip()
            line=line.split()
            list1.append(line)
        balance = float(((list1[4])[2]))     
        balance=balance+money
        (list1[4])[2]="%.2f"%balance # writing the new balance
        outfile=open( file + ".txt","w")
        for n in list1:
            for k in n:
                outfile.write(str(k))
                outfile.write(" ")
            outfile.write("\n")
        from time import ctime
        outfile.write("you have deposited " + str(money) + " SR in this date: "+ctime())
        outfile.close()
        print("Done")
    else :
        print("Unvalid Card Number.")
    infile.close()
    sleep(2) #make the function wait for two seconds
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program")

#7.
def payBillFun(money, cardNumber, file): #to transfer the money directly
    infile=open( file + ".txt","r")
    line1=infile.readline()
    list1=[]
    list2=[]
    if str(cardNumber) in line1 :
        nameOfTheBill=input("Enter the name of the bill: ")
        accountNumber=input("Enter the account number of this bil : ")
        #value=input("Enter the value of this bill : ")  #no need no need since in given in the functio
        line1=line1.rstrip()
        line1=line1.split()
        list1.append(line1)
        for line in infile:
            line=line.rstrip()
            line=line.split()
            list1.append(line)
        balance = float(((list1[4])[2]))
        if money > balance : #check if the balance enough, if not it will show a message asking to deposit money first.
            print ("Not enough balance please deposit " +str("%.2f"%(money-balance)) + " to deduct the bill")
        else:     
            balance=balance-money #if the balance enough it will deduct the money from the balance
            (list1[4])[2]="%.2f"%balance
            outfile=open( file + ".txt","w")
            for n in list1:
                for k in n:
                    outfile.write(str(k))
                    outfile.write(" ")
                outfile.write("\n")  
            from time import ctime
            outfile.write("You have paid "+str(nameOfTheBill)+ " bill number("+str(accountNumber)+") " + str(money) + " SR in this date: "+ctime())
            outfile.close()
            print("Done")
    else :
        print("Unvalid Card Number.")
    infile.close()
    sleep(2) #Again it will wait for two seconds then print the menu
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program")


#8.
def viewTransactionsFun(cardNumber): #this function is to view all transactions of the account.
    infile=open("cardNumber.txt","r")
    list1=[]
    line1=infile.readline()
    if str(cardNumber) in line1 :
        line1=line1.rstrip()
        list1.append(line1)
        for line in infile:
            line=line.rstrip()
            list1.append(line)
    if len(list1) > 5 :   #this to ignore the account informations
        for n in range (5,(len(list1))):
            print(list1[n])
    else :
        print ("no transactions")
    infile.close() 
    sleep(2)
    print("")
    print("Bank Account Program")
    print("="*30)
    print("%-5s"%"1."+"Show account information\n"+"%-5s"%"2."+"Change PIN number\n"+"%-5s"%"3."+"Whitdraw amount of money")
    print("%-5s"%"4."+"Deposit amount of money\n"+"%-5s"%"5."+"Pay bills\n"+"%-5s"%"6."+"View the last transactions")
    print("%-5s"%"7."+"Terminate a program")

#9.
def terminateFun(cardNumber, file): #No need for money in def  terminateFun (not(terminateFun(money, cardNumber, file):))
    infile=open( file + ".txt","r") #Here we will print the last transactions on (if any) and we will end the program
    list1=[]
    line1=infile.readline()
    if str(cardNumber) in line1 :
        line1=line1.rstrip()
        list1.append(line1)   
        for line in infile:
            line=line.rstrip()
            list1.append(line)
        if len(list1)==5:
            print("No transactions")
        else :
            print("the last transactions on this account")
            print(list1[len(list1)-1])
    infile.close()
    print("Goodbye , stay safe and healthy")
    
#main
def main():  #main used to arrange the program and calling each function if needed
    choice= input("Enter 'L' to login or 'S'to sign up: ")
    choice=choice.upper()
    if choice == "S" or choice =="L" :
        if choice == "S" :
            create()
        print("now you have to login")
        login()
        choice2= input("My choice is: ")
        while choice2 != "7": #It will keep running until the terminate function is called 
            if choice2=="1":
                show(file)
            elif choice2=="2":
                changePINFun(currentPIN,cardNumber,file)
            elif choice2=="3":
                money=float(input("How much? "))
                withdrawFun(money, cardNumber, file)
            elif choice2=="4":
                money=float(input("How much? "))
                depositFun(money, cardNumber, file) 
            elif choice2=="5":
                money=float(input("How much? "))
                payBillFun(money, cardNumber, file)
            else :
                 viewTransactionsFun(cardNumber)
            choice2= input("My choice is:")
        terminateFun(cardNumber,file)
       
    else : 
        print("Wrong input")
main()
# Out:
# Enter 'L' to login or 'S'to sign up: s
# Enter your Card Number : 12345
# Unvalid Card Number.
# Enter Card Number : 1234
# Enter PIN Code: 4321
# Enter you Email : s201936550@kfupm.edu.sa
# Enter The services that you want (seprte it by commaas(,)): test
# now you have to login
# Enter your card number : 1598
# Wrong card number
# Enter your card number : 1234
# Enter your Pin code : 4321
#
# Bank Account Program
# ...
# 1.   Show account information
# 2.   Change PIN number
# 3.   Whitdraw amount of money
# 4.   Deposit amount of money
# 5.   Pay bills
# 6.   View the last transactions
# 7.   Terminate a program
# My choice is: 1
# Card Number is : 1234
# PIN code is: 4321
# Email address is: s201936550@kfupm.edu.sa
# You extra service(s) : test
# Balance : 0.0
#
# Bank Account Program
# ...
# 1.   Show account information
# 2.   Change PIN number
# 3.   Whitdraw amount of money
# 4.   Deposit amount of money
# 5.   Pay bills
# 6.   View the last transactions
# 7.   Terminate a program
# ...
